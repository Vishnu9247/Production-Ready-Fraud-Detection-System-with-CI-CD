# %%
import requests
import pandas as pd
from sklearn.metrics import accuracy_score

# %%
url = 'http://127.0.0.1:8000/predict'
url2 = 'http://127.0.0.1:8000/predict'
url3 = 'https://credit-card-fraud.wonderfulstone-60fe1e35.westus2.azurecontainerapps.io/predict'

# %%
results = []
for i in range(1000):
    sample =  pd.read_csv('sample.csv').to_dict(orient='records')[i]
    response = requests.post(url3, json=sample)
    #print(f"Response for sample {i}: {response.json()}")
    results.append(response.json()['prediction'])

# %%
sample_target = pd.read_csv('sample.csv')['target'].tolist()

# %%
accuracy = accuracy_score(sample_target, results)
print(f"Accuracy of the API predictions: {accuracy:.2f}")
# Out:
# Accuracy of the API predictions: 0.42

# %%
sample_df = pd.DataFrame({'target': sample_target, 'prediction': results})

# %%
sample_df['target'].value_counts()
# Out:
# target
# 0    999
# 1      1
# Name: count, dtype: int64

# %%
sample_df['prediction'].value_counts()
# Out:
# prediction
# 1    581
# 0    419
# Name: count, dtype: int64

# %%
sample_df['target'].index[sample_df['target'] == 1].tolist()
# Out:
# [945]

# %%
sample_df['prediction'].index[sample_df['prediction'] == 1].tolist()
# Out:
# [0,
#  1,
#  2,
#  3,
#  4,
#  5,
#  6,
#  8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  14,
#  15,
#  17,
#  18,
#  19,
#  20,
#  21,
#  22,
#  23,
#  24,
#  26,
#  27,
#  29,
#  30,
#  33,
#  34,
#  35,
#  36,
#  38,
#  39,
#  40,
#  43,
#  44,
#  46,
#  47,
#  48,
#  49,
#  51,
#  52,
#  53,
#  54,
#  55,
#  56,
#  57,
#  59,
#  60,
#  61,
#  62,
#  63,
#  64,
#  66,
#  67,
#  68,
#  69,
#  71,
#  72,
#  74,
#  75,
#  77,
#  78,
#  79,
#  80,
#  81,
#  84,
#  85,
#  87,
#  88,
#  89,
#  90,
#  91,
#  92,
#  93,
#  94,
#  96,
#  98,
#  99,
#  100,
#  101,
#  102,
#  103,
#  104,
#  106,
#  107,
#  108,
#  109,
#  111,
#  112,
#  113,
#  114,
#  116,
#  117,
#  119,
#  120,
#  122,
#  124,
#  125,
#  126,
#  127,
#  128,
#  132,
#  134,
#  136,
#  137,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  144,
#  145,
#  146,
#  147,
#  148,
#  149,
#  150,
#  154,
#  155,
#  156,
#  157,
#  158,
#  159,
#  160,
#  161,
#  162,
#  163,
#  165,
#  166,
#  168,
#  170,
#  171,
#  173,
#  174,
# ...
